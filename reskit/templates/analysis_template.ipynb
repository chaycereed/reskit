# %% [markdown]
# # Notebook

# %%
# Set random seeds
import random
import numpy as np

random.seed(67)
np.random.seed(67)

# %%
# Import packages
import pandas as pd
import numpy as np

# %%
# Load your data here
# df = pd.read_csv("data/raw/example.csv")
